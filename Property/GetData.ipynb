# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# rumah123_url = 'https://www.rumah.com/rumah-dijual/di-area-depok-idjb10' #403

olx_url = 'https://www.olx.co.id/depok-kota_g4000024/dijual-rumah-apartemen_c5158?filter=type_eq_rumah'

# web99_url = 'https://www.99.co/id/jual/rumah/depok?hlmn=2' #403

# rumahdijual_url = 'https://rumahdijual.com/depok/'#403
rumah_trovit_url = 'https://rumah.trovit.co.id/rumah-murah-50-juta-depok'

url ='https://www.rumah.com/listing-properti/dijual-rumah-2-unit-type-85-50-dekat-gdc-oleh-raihan-hasanain-18498336'

# %%
from urllib.request import urlopen
page = urlopen(url)

# page = urlopen(rumah_trovit_url)

page
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-cba4fd298206> in <module>
#       1 from urllib.request import urlopen
# ----> 2 page = urlopen(url)
#       3
#       4 # page = urlopen(rumah_trovit_url)
#       5
#
# /usr/local/Cellar/python@3.8/3.8.10/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/local/Cellar/python@3.8/3.8.10/Frameworks/Python.framework/Versions/3.8/lib/python3.8/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# ...

# %%
html_bytes = page.read()
html = html_bytes.decode("utf-8")
print(html)
# Out:
# <!doctype html>
# <html lang="id">
#     <head>
#         <meta charset="utf-8">
#
#         <link rel="alternate" hreflang="id-id" href="https://www.olx.co.id/id-id/depok-kota_g4000024/dijual-rumah-apartemen_c5158?filter=type_eq_rumah">
#         <title data-rh="true">Dijual Rumah Dijual Murah &amp; Cari Rumah di Indonesia - OLX.co.id</title>
#         <meta data-rh="true" name="description" content="Dijual Rumah Murah di Indonesia, temukan listing Rumah terbaru hanya di OLX pusat jual beli Rumah terlengkap di Indonesia."/>
#         <link data-rh="true" rel="next" href="https://www.olx.co.id/depok-kota_g4000024/dijual-rumah-apartemen_c5158?filter=type_eq_rumah&amp;page=1"/><link data-rh="true" rel="canonical" href="https://www.olx.co.id/depok-kota_g4000024/dijual-rumah-apartemen_c5158?filter=type_eq_rumah"/>
#         <meta http-equiv="Content-Language" content="id">
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# ...
